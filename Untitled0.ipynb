# %% [markdown]
# <a href="https://colab.research.google.com/github/NiallPG/it612/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
# const addTax = (price, rate) => price * (1 + rate);
#
# // example 1
# console.log(addTax(100, 0.05));
#
# // example 2
# console.log(addTax(100, 0.1));
# Out:
# Overwriting code.js

# %%
# !node code.js
# Out:
# 105
# 110.00000000000001
